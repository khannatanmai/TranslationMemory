# %%
src_tm_words = [] #Content Words in Source TM

with open('tm_data/tm_src_2000_pp.txt') as src_tm:
    line = src_tm.readline()
    
    while line:
        line = line.rstrip() #Removing Trailing Whitespace
        
        words = line.split('\t')
        src_tm_words.append(words)
        
        line = src_tm.readline()

print(src_tm_words)
# Out:
# [['lead', 'blind', 'gone', 'astray', '.'], ['amazonis', 'quadrangle'], ['thus', 'requite', 'people', 'mujrimun', '(', 'disbelievers'], ['company', 'may', 'keep', 'changing', 'business', 'strategy', 'steady', 'pace', 'adapt', 'pressure', 'competition', '.'], ['daily', 'values', 'may', 'higher', 'lower', 'depending', 'calorie', 'needs', '.'], ['state', 'disbelieve', 'lord', 'deeds', 'like', 'ashes', 'strong', 'wind', 'blew', 'away', 'stormy', 'day', ';', 'got', 'nothing', 'earned', ';', 'extreme', 'error', '.'], ['forbid', 'good', 'things', 'allah', 'hath', 'made', 'lawful'], ['reason', 'people', 'create', 'goals', 'feel', 'getting', 'work', 'completed', 'within', 'time', 'frame', 'going', 'get', 'profit', 'later', 'stage', '.'], ['per', 'hisotrical', 'prooven', 'prooved', 'print', 'kuran', 'mirror', 'image', 'rela', 'print', 'kuran', 'created', 'hajrat', 'muhammad', '(', 'sall', '.', ')', '.'], ['controversies', 'surrounding', 'topic', 'many', 'songs', 'rafi', 'sing', 'lifetime', '.'], ['got', 'answers', 'voice', 'whirlwind'], ['divergency'], ['ye', 'doubt', 'concerning', 'religion', '--', 'worship', 'ye', 'worship', 'beside', 'allah'], ['kinsmen'], ['turned', ';', 'asking', 'someone', ';'], ['heaven', 'night-comer'], ['matter', 'resources', 'whether', 'living', 'non-living', '.'], ['secretion', 'come', 'girl', 'becomes', 'young', 'called', '`', '`', '`', 'primary', 'amenorrhoea', "'", "'", "'", 'secretion', 'stops', 'coming', 'called', '`', '`', '`', 'secondary', 'amenorrhoea', "'", "'", "'", '.'], ['level', 'bureaucratic', 'reshuffle', '.'], ['toothbrushing', '-', 'brush', 'morning', 'breakfast', 'night', 'child', "'s", 'last', 'meal/snack/drink', '.'], ['series', 'said', 'two', 'teams', 'test', 'match', 'played', 'runs', '5', 'days', '3', '5', 'matches', 'take', 'place', 'series', 'finished', 'time', 'draw', '.'], ['characteristic', 'length', 'robot', '.'], ['places', 'always', 'insecure', '.'], ['two', 'claims', 'tribunals', 'constituted', 'one', 'area', 'state'], ['hasan', 'akbar', ':', 'another', 'african-american', 'convert'], ['take', 'pride'], ['insert', 'buffer'], ['nevertheless'], ['say', ':', 'ye', 'tarried', 'little', 'ye', 'knew', '.'], ['disport'], ['red', 'tapism'], ['point', 'debate'], ['liked', 'liked', '?'], ['a.d', '.'], ['relief', 'eating', 'hot', 'fomentation', '.'], ['answer_id:8617'], ['defined', 'limits', 'work', 'slavery', 'individual', 'therefore', 'material', 'positions/', 'tools', 'must', 'strictly', 'regulated'], ['category', ':', 'rivers', 'uttarakhand'], ['say', 'thou', ':', 'delivereth', 'darknesses', 'land', 'sea'], ['might', 'want', 'think', ':'], ['firefighting'], ['leaflet', 'gives', 'basic', 'advice', 'benefits', 'tax', 'credits', 'may', 'able', 'get', '.'], ['montreal'], ['chest', 'wish', 'clean', 'chest'], ['arrogant', 'impatience', 'old', 'fanatical', 'devotion', 'perceived', 'rational', 'aesthetic'], ['said', 'u'], ['good', 'toucheth', 'begrudging', '.'], ['verily', 'god', 'admit', 'believe', 'right', 'gardens', 'streams', 'water', 'running', '.'], ['policy', 'causing', 'gridlock', '.'], ['indian', 'people', 'basically', 'lot', 'brainpower'], ['like', 'smoke', 'emitter'], ['causes', 'laughter', 'weeping', '.'], ['africans', 'similar'], ['people', 'rightly', 'following', 'lord', 'shall', 'successful', '.'], ['biocompatible', 'metal', 'ion', 'impregnated', 'polymeric', 'nanocomposite', 'films', 'efficient', 'antibacterial', 'materials', '.'], ['give', 'eat', '.'], ['somatic'], ['save', 'custom', 'view', '...'], ['ss_tv_stv_sst_tvvv'], ['control', 'sap-sucking', 'insect'], ['ill-fitting', 'clothes', 'clothes', 'big', 'give', 'bloated', 'look', 'tight-fitting', 'clothes', 'accentuate', 'body', 'non-formal', 'way', '.'], ['relevant', 'goals', 'aim', 'like', 'situation', '.'], ['neighbour', 'radio'], ['sure', 'shall', 'try', 'something', 'fear', 'hunger', 'loss', 'wealth', 'life', 'fruits', '(', 'labour', ')', ';', 'give', 'tidings', 'happiness', 'patience'], ['low', 'literacy', 'rate', '.'], ...

# %%
indexed_dict = {}
count = 0

for sentence in src_tm_words:
    count += 1
    for word in sentence:
        if word not in indexed_dict:
            indexed_dict[word] = [count]
        else:
            indexed_dict[word].append(count)

            
print(indexed_dict)
# Out:
# {'': [114, 125, 144, 166, 209, 218, 279, 367, 445, 479, 486, 735, 820, 846, 892, 896, 975, 983, 1064, 1093, 1167, 1184, 1226, 1249, 1399, 1446, 1517, 1633, 1648, 1684, 1804, 1869, 1907, 1960], 'requite': [3], 'brave': [592], 'effective': [309, 364, 769], 'shaping': [1761], 'grew': [1961], 'samsung': [1474, 1548], 'gibraltar': [1678], 'transportation': [1336], 'biochemic': [1728], 'presides': [681], 'cave': [1609], 'css': [844, 1644], 'respect': [1557, 1775, 1775], 'educational': [225, 809], 'faced': [1910], 'poems': [888], 'mission': [555], 'know': [72, 524, 530, 569, 642, 906, 1025, 1326, 1687, 1761, 1878], 'century': [1602, 1965], 'media': [138, 1169, 1772], 'journey': [113, 426, 764, 909], 'falls': [786], 'effect': [1773], 'profit': [8, 312], 'himalayas': [1945], 'insect': [60], 'lawful': [7], 'diagnosis': [1494], 'denied': [155], 'buddhism': [496], 'extra': [937, 1931], 'paper': [1181, 1871], 'crore': [1576], 'argumentative': [1685], 'iran': [430], 'rashes': [1856], 'kick-ass': [1881], 'whirlwind': [11], 'st': [229], 'later': [8, 409, 828, 1111, 1408], 'noun': [775], 'turned': [15, 205, 712, 1334], 'grasshoppers': [95], 'game': [1533], 'offender': [419], 'mostly': [871, 961, 1492], 'bhash': [732], 'kingdoms': [999],